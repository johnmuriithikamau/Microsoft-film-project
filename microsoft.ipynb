# %% [markdown]
# # Project for microsoft getting into films Business
#
# ## Introduction
# Microsoft sees all the big companies creating original video content and they want to get in on the fun. They have decided to create a new movie studio, but they don’t know anything about creating movies. We will be  exploring what types of films are currently doing the best at the box office then translate those findings into actionable insights that the head of Microsoft's new movie studio will use to help decide what type of films to create.
#
# ## Objectives
#
# *  Reading im.db.zip and bom.movie_gross.csv.gz data from files into Python objects
# * Exploring what types of films are currently doing the best at the box office.
# * Cleaning data (filtering, normalizing locations, converting types)
# *  Combine data from multiple sources into a single data structure
# *  Interpret descriptive statistics and data visualizations to present findings
#
#
# ### Business Understanding
#
#
# Market Analysis: Understanding the target audience, market trends, and audience preferences is crucial. Analyzing box office data, genre popularity, and audience demographics helps identify potential market opportunities.
#
# Revenue Streams: Films generate revenue through various channels, including box office sales, home video/DVD sales, streaming platforms, TV rights, merchandise, and licensing. Understanding these revenue streams and their potential is vital for financial planning.
#
# Marketing and Promotion: Successful films require effective marketing and promotion to reach the target audience. This involves creating compelling trailers, advertising campaigns, social media presence, press releases, and engaging with influence's and critics.
#
# Intellectual Property: Protecting intellectual property rights is essential in the film industry. This includes securing copyrights, trademarks, and dealing with licensing agreements for adaptations, sequels, and merchandise.
#
# Risk Management: Assessing and managing risks in film production, such as production delays, budget overruns, talent availability, and audience reception, is important to minimize potential setbacks.
#
# Legal and Regulatory Considerations: Complying with legal and regulatory requirements related to filming permits, labor laws, taxation, and distribution contracts is essential for smooth operations.
#
# By understanding these business aspects, film producers, distributors, and stakeholders can make informed decisions, increase the chances of success, and effectively navigate the dynamic landscape of the film industry.
# ###  Data Understanding
#
#
#
#
#
#
# Data Analysis
# Visualization
# Code Quality

# %% [markdown]
# ### Data Preparation

# %%
import pandas as pd
import csv
import sqlite3

# %%
bom_movie_gross = pd.read_csv('bom.movie_gross.csv.gz', index_col=0)
title_rating = pd.read_csv("imdb.title.ratings.csv.gz", index_col=0)
#rt_review = pd.read_csv("rt.reviews.tsv.gz", index_col=0)
movie_budgets = pd.read_csv("tn.movie_budgets.csv.gz", index_col=0)

# %%
bom_movie_gross
# Out:
#                                                  studio  domestic_gross  \
# title
# Toy Story 3                                          BV     415000000.0
# Alice in Wonderland (2010)                           BV     334200000.0
# Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# Inception                                            WB     292600000.0
# Shrek Forever After                                P/DW     238700000.0
# ...                                                 ...             ...
# The Quake                                         Magn.          6200.0
# Edward II (2018 re-release)                          FM          4800.0
# El Pacto                                           Sony          2500.0
# The Swan                                     Synergetic          2400.0
# An Actor Prepares                                 Grav.          1700.0
#
#                                             foreign_gross  year
# title
# ...

# %%
bom_movie_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3387 entries, Toy Story 3 to An Actor Prepares
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   studio          3382 non-null   object
#  1   domestic_gross  3359 non-null   float64
#  2   foreign_gross   2037 non-null   object
#  3   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 132.3+ KB
